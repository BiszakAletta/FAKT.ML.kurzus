# %% [markdown]
# <a href="https://colab.research.google.com/github/BiszakAletta/FAKT.ML.kurzus/blob/main/elsohazi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Képek beolvasása

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
kezilabda =plt.imread('/content/drive/My Drive/Machine learning FAKT/kezilabda.jpg')
kisherceg = plt.imread('/content/drive/My Drive/Machine learning FAKT/kisherceg.png')
vasarely = plt.imread('/content/drive/My Drive/Machine learning FAKT/vasarely.jpg')

# %%
plt.imshow(kezilabda)

# %%
plt.imshow(kisherceg)

# %%
plt.imshow(vasarely)

# %%
kezilabda.shape
# Out:
# (480, 955, 3)

# %%
print(type(kezilabda))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Zajkép

# %%
import random
print(random.randint(0,256))
# Out:
# 175

# %%
ize = np.random.randint(0,255,(480,955,3))

# %%
plt.imshow(ize)

# %%
ize[:,:,1]
# Out:
# array([[102,  76, 102, ..., 222, 222, 200],
#        [225, 146, 208, ...,   9, 251, 215],
#        [ 72, 174, 126, ..., 242,  79,   1],
#        ...,
#        [ 66, 135, 188, ..., 242, 129,  15],
#        [246,  24,  42, ..., 244, 186, 110],
#        [160, 195, 109, ..., 104, 165, 109]])

# %% [markdown]
# RGB csatornák a zajképen

# %%
plt.imshow(ize[:,:,1])

# %%
plt.imshow(ize[:,:,0])

# %%
plt.imshow(ize[:,:,2])

# %%
fig, axs = plt.subplots(2,2)
fig.suptitle('Mind a 4 kép')
axs[0,0].imshow(kezilabda)
axs[0,1].imshow(kisherceg)
axs[1,0].imshow(vasarely)
axs[1,1].imshow(ize)

# %%
for i in range(3):
  print(kezilabda[:,:,i].mean())
  print(kisherceg[:,:,i].mean())
  print(vasarely[:,:,i].mean())
# Out:
# 177.21911431064572
# 0.91325635
# 83.7852688172043
# 157.9799280104712
# 0.8913315
# 89.83649940262843
# 156.8246662303665
# 0.831543
# 125.2226403823178

# %% [markdown]
# Képszerkesztés

# %%
from PIL import Image

# %%
vasarely2 = Image.open('/content/drive/My Drive/Machine learning FAKT/vasarely.jpg')

# %%
vasarely2 = Image.fromarray(vasarely)

# %%
vasarely2
# Out:
# <PIL.Image.Image image mode=RGBA size=279x300 at 0x7FC0F5957810>

# %%
vasarely3 = vasarely2.rotate(55)

# %%
vasarely3
# Out:
# <PIL.Image.Image image mode=RGBA size=279x300 at 0x7FC0F5A1FA50>

# %%
vasarely2.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=279x300 at 0x7FC0F5D56B10>

# %%
vasarely2.resize(size=(500,500))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x500 at 0x7FC0F59CDA10>
